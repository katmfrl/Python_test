# %%
for x in range(5) :
    print ("x;" , x)
# Out:
# x; 0
# x; 1
# x; 2
# x; 3
# x; 4

# %%
a=3
b=5
print(a+b)
# Out:
# 8

# %%
import numpy as np
np.linspace(1,100,num=20)
# Out:
# array([  1.        ,   6.21052632,  11.42105263,  16.63157895,
#         21.84210526,  27.05263158,  32.26315789,  37.47368421,
#         42.68421053,  47.89473684,  53.10526316,  58.31578947,
#         63.52631579,  68.73684211,  73.94736842,  79.15789474,
#         84.36842105,  89.57894737,  94.78947368, 100.        ])

# %%
import numpy as np
np.random(0.1 num=10)
# Out:
#   File "<ipython-input-11-25f2a0f46678>", line 2
#     np.random(0.1 num=10)
#                     ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
from itertools import repeat
a = ["A01","A02","A03","A04","A05"]
b = ["201501","201502","201503","201504","201505"]
c = ["100","150","130",None,"200"]
my_dict = dict(col1=a,col2=b,col3=c)
testdf = pd.DataFrame(my_dict)
testdf
# Out:
#   col1    col2  col3
# 0  A01  201501   100
# 1  A02  201502   150
# 2  A03  201503   130
# 3  A04  201504  None
# 4  A05  201505   200

# %%
testdf.columns=["REGIONID","YEARWEEK","QTY"]
testdf.head()
# Out:
#   REGIONID YEARWEEK   QTY
# 0      A01   201501   100
# 1      A02   201502   150
# 2      A03   201503   130
# 3      A04   201504  None
# 4      A05   201505   200

# %%
nullDf = testdf[testdf['QTY'].isnull()]

# %%
import pandas as pd
from itertools import repeat
pd.read_csv("C:/Users/SMART-19/Python_practice/kopo_product_volume_2.csv", encoding="ms949")
# Out:
#     REGIONID PRODUCTGROUP  YEARWEEK   VOLUME    이동평균 (15)           변동률  \
# 0        A01       ST0001    201501   513598  509442.0000   2904.314794
# 1        A01       ST0001    201502   438251  516120.1111   3010.428137
# 2        A01       ST0001    201503   420290  515676.0000   4371.071109
# 3        A01       ST0001    201504   458431  516504.2727   6032.104522
# 4        A01       ST0001    201505   482381  514004.6667  10856.747410
# 5        A01       ST0001    201506   570412  510622.7692  17230.602410
# 6        A01       ST0001    201507   620392  504735.0714  24419.458070
# 7        A01       ST0001    201508   571781  525095.6667  31118.702550
# 8        A01       ST0001    201509   569545  541850.9333  36402.672160
# 9        A01       ST0001    201510   511679  559134.3333  38637.601200
# 10       A01       ST0001    201511   524787  575879.2667  37054.983600
# 11       A01       ST0001    201512   486509  590834.3333  30410.588020
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
x = np.linspace(0,5,11)
y=x**2
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
x=np.linspace(1,20,2)
y=x**2
plt.plot(x,y)

# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
studentData = pd. read_csv("C:/Users/SMART-19/Python_practice/student_middle_result.csv")
studentData
# Out:
#      ST_NO   SW   DB  AND
# 0   ST0001   95   30    0
# 1   ST0002   50   50    0
# 2   ST0003   15   30   15
# 3   ST0004   90   50   20
# 4   ST0005   75   20   20
# 5   ST0006  100   80   30
# 6   ST0007   15   10   30
# 7   ST0008  100  100   33
# 8   ST0009   65   60   35
# 9   ST0010   90   20   38
# 10  ST0011  100   70   43
# 11  ST0012   90   45   45
# 12  ST0013   90   60   47
# 13  ST0014  100  100   48
# 14  ST0015   75   80   49
# 15  ST0016   90  100   50
# 16  ST0017  100   30   50
# 17  ST0018  100  100   58
# 18  ST0019  100  100   60
# 19  ST0020   90   80   69
# 20  ST0021  100  100   75
# 21  ST0022  100  100   95
# 22  ST0023  100  100   96
# 23  ST0024  100  100  100
# 24  ST0025   90  100  100
# 25  ST0026  100  100  100

# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
studentData = pd. read_csv("C:/Users/SMART-19/Python_practice/student_middle_result.csv")
name = studentData[['ST_NO']]
feature = studentData [['SW','DB','AND']]
model = KMeans(n_clusters=2,algorithm='auto')
model.fit(feature)
predict = pd. DataFrame(model.predict(feature))
predict.columns=['PREDICT']
r = pd.concat([name,feature,predict],axis=1)
plt.scatter(r['DB'],r['AND'],c=r['PREDICT'],alpha=0.5)
plt.show()

# %%
a=3
A=5

print(a)
print(A)
# Out:
# 3
# 5

# %%
integer_value = 123
float_value= 12.456

sum=integer_value+float_value
print(sum)

multiple = integer_value*float_value
print(multiple)

division = integer_value/float_value
print(division)

integer_value2 = int(float_value)
exponential = integer_value2**2
print(exponential)

mod = integer_value%int(float_value)
print(mod)
# Out:
# 135.456
# 1532.088
# 9.8747591522158
# 144
# 3
